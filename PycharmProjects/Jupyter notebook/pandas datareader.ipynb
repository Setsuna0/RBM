# %% [markdown]
# Using pandas rolling function

# %% [markdown]
# 1. Set up environment

# %%
import numpy as np
import pandas as pd
import pandas_datareader as pdr
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# D:\Software\Anaconda3\envs\pytorch\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# 2. Get data from yahoo.finance

# %%
gld = pdr.get_data_yahoo('GLD','2016-11-08')
gld.head()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2016-11-08  123.089996  121.360001  122.120003  121.639999   9480600
# 2016-11-09  124.349998  121.110001  124.300003  121.559998  18236500
# 2016-11-10  121.540001  119.379997  121.519997  119.750000  22268000
# 2016-11-11  119.690002  116.230003  119.650002  117.099998  20381800
# 2016-11-14  117.139999  115.489998  116.120003  116.110001  20729400
#
#              Adj Close
# Date
# 2016-11-08  121.639999
# 2016-11-09  121.559998
# 2016-11-10  119.750000
# 2016-11-11  117.099998
# 2016-11-14  116.110001

# %% [markdown]
# 3. Discard unneeded data

# %%
gld_close = pd.DataFrame(gld.Close)
print(gld_close)
# Out:
#                  Close
# Date
# 2016-11-08  121.639999
# 2016-11-09  121.559998
# 2016-11-10  119.750000
# 2016-11-11  117.099998
# 2016-11-14  116.110001
# ...                ...
# 2020-02-20  152.410004
# 2020-02-21  154.699997
# 2020-02-24  156.089996
# 2020-02-25  153.300003
# 2020-02-26  153.970001
#
# [829 rows x 1 columns]

# %% [markdown]
# 4. Use rolling method to compute moving averages

# %%
gld_close['MA_9'] = gld_close.Close.rolling(9).mean()
gld_close['MA_21'] = gld_close.Close.rolling(21, center=True).mean()

# %% [markdown]
# 5. Plot data and moving averages

# %%
plt.figure(figsize=(15,10))
plt.grid(True)
plt.plot(gld_close['Close'],label='GLD')
plt.plot(gld_close['MA_9'],label='MA 9 day')
plt.plot(gld_close['MA_21'],label='MA 21 day')
plt.legend(loc=2)
